# %%
import pandas as pd 
import os 
import numpy as np

# %%
target_filename = "/home/dhakal/MoBI/data/ROSMAP/methy.csv"
target_df = pd.read_csv(target_filename)
target_df.head()
# Out:
#    Unnamed: 0  ENSG00000161896.6  ENSG00000248714.2  ENSG00000242349.1  \
# 0           1           0.181381           0.125337           0.094807
# 1           2           0.132848           0.099462           0.149573
# 2           3           0.111206           0.069999           0.127883
# 3           4           0.085876           0.129139           0.071849
# 4           5           0.068125           0.121434           0.008678
#
#    ENSG00000006831.9  ENSG00000261195.1  ENSG00000143409.11  \
# 0           0.480227           0.246111            0.370208
# 1           0.487058           0.377940            0.358607
# 2           0.412276           0.198039            0.289383
# 3           0.473626           0.231430            0.393466
# 4           0.453002           0.150118            0.340528
#
#    ENSG00000140931.15  ENSG00000185499.11  ENSG00000101265.10  ...  \
# 0            0.214085            0.230799            0.427630  ...
# ...

# %%
data_path = "/home/dhakal/MoBI/data/KIRP/KIRP_methy.txt"
data_df = pd.read_csv(data_path, sep = "\t")
data_df.head()
# Out:
#    cg00000714  cg00001349  cg00002808  cg00003287  cg00005297  cg00005847  \
# 0    0.150420    0.883862    0.928517    0.238733    0.077386    0.819761
# 1    0.097150    0.956406    0.962285    0.079086    0.098345    0.891402
# 2    0.109288    0.933165    0.924958    0.354007    0.380825    0.753833
# 3    0.354945    0.910085    0.939584    0.119912    0.192618    0.645733
# 4    0.393214    0.910353    0.925015    0.246463    0.175352    0.856279
#
#    cg00007420  cg00008629  cg00008665  cg00008971  ...  ch.7.1866993F  \
# 0    0.173142    0.160634    0.612533    0.380217  ...       0.213569
# 1    0.099811    0.305202    0.843000    0.787062  ...       0.154313
# 2    0.192110    0.281908    0.568176    0.615717  ...       0.264444
# 3    0.342076    0.496417    0.712672    0.897817  ...       0.236547
# 4    0.221060    0.252641    0.764657    0.850553  ...       0.334073
#
#    ch.7.2254086F  ch.7.246556R  ch.7.3102217F  ch.8.1022548F  ch.8.1084391F  \
# ...

# %%
data_path = "/home/dhakal/MoBI/data/LUSC/LUSC_methy.txt"
data_df = pd.read_csv(data_path, sep = "\t")
data_df.head()
# Out:
#    cg18757087  cg00557293  cg26901352  cg27392802  cg16817426  cg14723423  \
# 0    0.777804    0.019783    0.745695    0.983683    0.768561    0.787845
# 1    0.301071    0.040133    0.374461    0.439967    0.481931    0.664181
# 2    0.626105    0.025983    0.624935    0.969899    0.762611    0.686697
# 3    0.816331    0.029152    0.158232    0.337633    0.651366    0.445135
# 4    0.698929    0.026265    0.747258    0.861165    0.681008    0.701119
#
#    cg21082921  cg03051449  cg23859055  cg19570171  ...  cg00473597  \
# 0    0.084693    0.593774    0.520233    0.021191  ...    0.856295
# 1    0.083993    0.402678    0.238698    0.029297  ...    0.372826
# 2    0.092482    0.161999    0.519110    0.024612  ...    0.748506
# 3    0.060770    0.706418    0.272604    0.025100  ...    0.637945
# 4    0.087367    0.525025    0.506361    0.023213  ...    0.789155
#
#    cg13375538  cg14242958  cg10653131  cg09384137  cg03024678  cg19974854  \
# ...

# %%
labels_filename = "/home/dhakal/MoBI/data/KIRP/KIRP_label.txt"
labels_df  = pd.read_csv(labels_filename, sep="\t")
labels_df.head()
# Out:
#    stage
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
labels_filename = "/home/dhakal/MoBI/data/LUSC/LUSC_label.txt"
labels_df  = pd.read_csv(labels_filename, sep="\t")
labels_df.head()
# Out:
#    stage
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
len(data_df), len(labels_df)
# Out:
# (362, 362)

# %%
len(labels_df), len(data_df)
# Out:
# (255, 255)

# %%
df = pd.concat([labels_df, data_df], axis=1)
df.head()
# Out:
#    stage  cg00000714  cg00001349  cg00002808  cg00003287  cg00005297  \
# 0      1    0.150420    0.883862    0.928517    0.238733    0.077386
# 1      1    0.097150    0.956406    0.962285    0.079086    0.098345
# 2      1    0.109288    0.933165    0.924958    0.354007    0.380825
# 3      1    0.354945    0.910085    0.939584    0.119912    0.192618
# 4      1    0.393214    0.910353    0.925015    0.246463    0.175352
#
#    cg00005847  cg00007420  cg00008629  cg00008665  ...  ch.7.1866993F  \
# 0    0.819761    0.173142    0.160634    0.612533  ...       0.213569
# 1    0.891402    0.099811    0.305202    0.843000  ...       0.154313
# 2    0.753833    0.192110    0.281908    0.568176  ...       0.264444
# 3    0.645733    0.342076    0.496417    0.712672  ...       0.236547
# 4    0.856279    0.221060    0.252641    0.764657  ...       0.334073
#
#    ch.7.2254086F  ch.7.246556R  ch.7.3102217F  ch.8.1022548F  ch.8.1084391F  \
# ...

# %%
curr_col_names = list(df.columns)
curr_col_names[0] = 'Label'
df.columns = curr_col_names
df.head(20)
# Out:
#     Label  cg00000714  cg00001349  cg00002808  cg00003287  cg00005297  \
# 0       1    0.150420    0.883862    0.928517    0.238733    0.077386
# 1       1    0.097150    0.956406    0.962285    0.079086    0.098345
# 2       1    0.109288    0.933165    0.924958    0.354007    0.380825
# 3       1    0.354945    0.910085    0.939584    0.119912    0.192618
# 4       1    0.393214    0.910353    0.925015    0.246463    0.175352
# 5       1    0.175971    0.891752    0.945606    0.056066    0.081994
# 6       1    0.238467    0.936737    0.931063    0.036882    0.069997
# 7       1    0.221784    0.850632    0.938421    0.065669    0.070874
# 8       1    0.254575    0.855476    0.939404    0.096366    0.483813
# 9       1    0.183494    0.831346    0.935389    0.228137    0.063666
# 10      1    0.173647    0.950896    0.908074    0.099233    0.325954
# 11      0    0.081117    0.912260    0.955291    0.840799    0.777113
# ...

# %%
#create train test split indices from sklearn 
len(df)
train_splits = [1 for i in range(int(0.8*len(df)))] + [0 for i in range(int(0.2*len(df)))]
from random import shuffle
shuffle(train_splits)
df['Split'] = train_splits 
df.head(100)
# Out:
#     Label  cg00000714  cg00001349  cg00002808  cg00003287  cg00005297  \
# 0       1    0.150420    0.883862    0.928517    0.238733    0.077386
# 1       1    0.097150    0.956406    0.962285    0.079086    0.098345
# 2       1    0.109288    0.933165    0.924958    0.354007    0.380825
# 3       1    0.354945    0.910085    0.939584    0.119912    0.192618
# 4       1    0.393214    0.910353    0.925015    0.246463    0.175352
# ..    ...         ...         ...         ...         ...         ...
# 95      1    0.200456    0.881499    0.953551    0.110920    0.047257
# 96      0    0.196482    0.913160    0.934819    0.053934    0.079462
# 97      1    0.333319    0.973551    0.935188    0.108155    0.209116
# 98      1    0.081138    0.912215    0.950319    0.104027    0.081767
# 99      0    0.103975    0.932946    0.930178    0.135473    0.542691
#
#     cg00005847  cg00007420  cg00008629  cg00008665  ...  ch.7.2254086F  \
# ...

# %%
np.unique(df['Label'])
# Out:
# array([0, 1])
