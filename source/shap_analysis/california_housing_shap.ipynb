# %%
import sklearn

import shap

# a classic housing price dataset
X, y = shap.datasets.california(n_points=1000)

X100 = shap.utils.sample(X, 100)  # 100 instances for use as the background distribution

# a simple linear model
model = sklearn.linear_model.LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
print("Model coefficients:\n")
for i in range(X.shape[1]): 
    print(X.columns[i], "=", model.coef_[i].round(5))
# Out:
# Model coefficients:
#
# MedInc = 0.42563
# HouseAge = 0.01033
# AveRooms = -0.1161
# AveBedrms = 0.66385
# Population = 3e-05
# AveOccup = -0.26096
# Latitude = -0.46734
# Longitude = -0.46272

# %%
explainer = shap.Explainer(model.predict, X100)
shap_values = explainer(X)

# %%
X.shape
# Out:
# (1000, 8)

# %%
shap_values.shape
# Out:
# (1000, 8)

# %%
sample_ind = 0
shap.plots.waterfall(shap_values[5], max_display=14)

# %%
print(shap_values[4])
# Out:
# .values =
# array([ 0.54059113, -0.02573316,  0.14485365, -0.06071259, -0.02630121,
#         0.31864625, -0.96925909,  1.39504273])
#
# .base_values =
# 1.903533811965417
#
# .data =
# array([   5.0049    ,   25.        ,    4.31926121,    1.03957784,
#         649.        ,    1.71240106,   37.79      , -122.43      ])
